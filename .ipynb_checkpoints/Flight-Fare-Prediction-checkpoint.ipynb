# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Importing the Datasets

# %%
# The Dataset is available on Kaggle at this link :- https://www.kaggle.com/datasets/nikhilmittal/flight-fare-prediction-mh

df = pd.read_excel("D:\\DataScience\\Machine-Learning-Projects\\Flight-Fare-Prediction\Datasets\\Data_Train.xlsx")
x_test = pd.read_excel("D:\\DataScience\\Machine-Learning-Projects\\Flight-Fare-Prediction\Datasets\\Test_set.xlsx")
y_test = pd.read_excel("D:\\DataScience\\Machine-Learning-Projects\\Flight-Fare-Prediction\Datasets\\Sample_submission.xlsx")

# %%
df.shape
# Out:
# (10683, 11)

# %%
x_test.shape
# Out:
# (2671, 10)

# %%
x_test["Price"] = y_test

# %%
x_test.head()
# Out:
#              Airline Date_of_Journey    Source Destination            Route  \
# 0        Jet Airways       6/06/2019     Delhi      Cochin  DEL → BOM → COK
# 1             IndiGo      12/05/2019   Kolkata    Banglore  CCU → MAA → BLR
# 2        Jet Airways      21/05/2019     Delhi      Cochin  DEL → BOM → COK
# 3  Multiple carriers      21/05/2019     Delhi      Cochin  DEL → BOM → COK
# 4           Air Asia      24/06/2019  Banglore       Delhi        BLR → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops              Additional_Info  \
# 0    17:30  04:25 07 Jun  10h 55m      1 stop                      No info
# 1    06:20         10:20       4h      1 stop                      No info
# 2    19:15  19:00 22 May  23h 45m      1 stop  In-flight meal not included
# 3    08:00         21:00      13h      1 stop                      No info
# 4    23:55  02:45 25 Jun   2h 50m    non-stop                      No info
#
#    Price
# 0  15998
# 1  16612
# 2  25572
# 3  25778
# ...

# %%
# concatinating x_train, and x_test

df = pd.concat([df, x_test], ignore_index= True)

# %% [markdown]
# # Simple PreProcessing

# %% [markdown]
# ### Observations: -
#
# **Problems**
#
# * Route and Total_Stops has 1 missing value
# * Airline should be of categorical type
# * Date_of_Journey is Object type it should be of DateTime type
# * Source should be of categorical type
# * Destination should be of categorical type
# * Route has some info. in it, Preprocessing need to be done.
# * Dep_Time should be of type DateTime
# * Arrival_Time should be of type DateTime.
# * Duration should be of type DateTime.
# * Total_Stops should be of type Category.
# * Additional_Info need to be preprocessed.
# * Price Column has some outliers.
# * There are 220 duplicated values in the dataset.

# %%
df.head(3)
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13354 entries, 0 to 13353
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          13354 non-null  object
#  1   Date_of_Journey  13354 non-null  object
#  2   Source           13354 non-null  object
#  3   Destination      13354 non-null  object
#  4   Route            13353 non-null  object
#  5   Dep_Time         13354 non-null  object
#  6   Arrival_Time     13354 non-null  object
#  7   Duration         13354 non-null  object
#  8   Total_Stops      13353 non-null  object
#  9   Additional_Info  13354 non-null  object
#  10  Price            13354 non-null  int64
# dtypes: int64(1), object(10)
# memory usage: 1.1+ MB

# %%
df.describe()
# Out:
#               Price
# count  13354.000000
# mean   11301.720009
# std     6452.843082
# min     1759.000000
# 25%     6135.250000
# 50%    10262.000000
# 75%    14781.000000
# max    79512.000000

# %%
df.duplicated().sum()  # 220 Duplicated values are available in the DataFrame.
# Out:
# 220

# %%
df.isnull().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              1
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        1
# Additional_Info    0
# Price              0
# dtype: int64

# %%
df.shape
# Out:
# (13354, 11)

# %%
df["Total_Stops"].value_counts()
# Out:
# Total_Stops
# 1 stop      7056
# non-stop    4340
# 2 stops     1899
# 3 stops       56
# 4 stops        2
# Name: count, dtype: int64

# %% [markdown]
# ### Type Conversion of Columns

# %%
# Converting Airline column from object to Category
df["Airline"] = df["Airline"].astype("category")

# Converting Date-of-Journey column from object to Datetime
df["Date_of_Journey"] = pd.to_datetime(df["Date_of_Journey"])

# Converting Source column from object to Category
df["Source"] = df["Source"].astype("category")

# Converting Destination column from object to Category
df["Destination"] = df["Destination"].astype("category")

# Converting Dep_Time column from object to Datetime
df["Dep_Time"] = pd.to_timedelta(df['Dep_Time'] + ":00")

# Converting Arrival_Time column from object to Datetime
df["Arrival_Time"] = pd.to_timedelta(df['Arrival_Time'] + ":00")

# Converting Duration column from object to Datetime
df["Duration"] = pd.to_timedelta(df['Duration'].str.replace("h", "hours").str.replace("m", "minutes"))

# Converting Total_Stops column from object to Category
df["Total_Stops"] = df["Total_Stops"].astype("category")

# Converting Additional_Info column from object to Category
df["Additional_Info"] = df["Additional_Info"].astype("category")
# Out:
# C:\Users\DIWAKAR SINGH\AppData\Local\Temp\ipykernel_3100\2770742995.py:5: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df["Date_of_Journey"] = pd.to_datetime(df["Date_of_Journey"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13354 entries, 0 to 13353
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          13354 non-null  category
#  1   Date_of_Journey  13354 non-null  datetime64[ns]
#  2   Source           13354 non-null  category
#  3   Destination      13354 non-null  category
#  4   Route            13353 non-null  object
#  5   Dep_Time         13354 non-null  timedelta64[ns]
#  6   Arrival_Time     13354 non-null  timedelta64[ns]
#  7   Duration         13354 non-null  timedelta64[ns]
#  8   Total_Stops      13353 non-null  category
#  9   Additional_Info  13354 non-null  category
#  10  Price            13354 non-null  int64
# dtypes: category(5), datetime64[ns](1), int64(1), object(1), timedelta64[ns](3)
# memory usage: 692.7+ KB

# %%
df.head(3)
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      2019-03-24  Banglore   New Delhi              BLR → DEL
# 1    Air India      2019-05-01   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways      2019-06-09     Delhi      Cochin  DEL → LKO → BOM → COK
#
#          Dep_Time    Arrival_Time        Duration Total_Stops Additional_Info  \
# 0 0 days 22:20:00 0 days 18:02:00 0 days 02:50:00    non-stop         No info
# 1 0 days 05:50:00 0 days 13:15:00 0 days 07:25:00     2 stops         No info
# 2 0 days 09:25:00 1 days 21:50:00 0 days 19:00:00     2 stops         No info
#
#    Price
# 0   3897
# 1   7662
# 2  13882

# %% [markdown]
# # EDA ( Exploratory Data Analysis )

# %%
df.head(2)
# Out:
#      Airline Date_of_Journey    Source Destination                  Route  \
# 0     IndiGo      2019-03-24  Banglore   New Delhi              BLR → DEL
# 1  Air India      2019-05-01   Kolkata    Banglore  CCU → IXR → BBI → BLR
#
#          Dep_Time    Arrival_Time        Duration Total_Stops Additional_Info  \
# 0 0 days 22:20:00 0 days 18:02:00 0 days 02:50:00    non-stop         No info
# 1 0 days 05:50:00 0 days 13:15:00 0 days 07:25:00     2 stops         No info
#
#    Price
# 0   3897
# 1   7662

# %% [markdown]
# ### Airline
#
# * Some of the Airlines has very less data, those airlines are :- Jet Airways Business, Multiple carriers Premium economy, Trujet, Vistara Premium economy
#
# Solutions :-
#
# * Remove the enteries of these airlines.

# %%
df["Airline"].value_counts()
# Out:
# Airline
# Jet Airways                          4746
# IndiGo                               2564
# Air India                            2192
# Multiple carriers                    1543
# SpiceJet                             1026
# Vistara                               608
# Air Asia                              405
# GoAir                                 240
# Multiple carriers Premium economy      16
# Jet Airways Business                    8
# Vistara Premium economy                 5
# Trujet                                  1
# Name: count, dtype: int64

# %%
df["Airline"].value_counts().plot(kind = "bar")
# Out:
# <Axes: xlabel='Airline'>

# %%
sns.boxplot(df, x = df["Airline"], y = df["Price"])
plt.xticks(rotation = "vertical")
plt.show()
# Out:
# D:\Python\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %%
# Drop the Airlines Values who has the very less data

filtered_airlines_list = df["Airline"].value_counts()[df["Airline"].value_counts().values > 20].index.to_list()

df = df[df["Airline"].isin(filtered_airlines_list)]

# %%
filtered_airlines_list = df["Airline"].value_counts().dropna()[df["Airline"].value_counts().dropna().values > 20].index.to_list()
df = df[df["Airline"].isin(filtered_airlines_list)]

# %%
filtered_airlines_list
# Out:
# ['Jet Airways',
#  'IndiGo',
#  'Air India',
#  'Multiple carriers',
#  'SpiceJet',
#  'Vistara',
#  'Air Asia',
#  'GoAir']

# %%
df["Airline"].value_counts()
# Out:
# Airline
# Jet Airways                          4746
# IndiGo                               2564
# Air India                            2192
# Multiple carriers                    1543
# SpiceJet                             1026
# Vistara                               608
# Air Asia                              405
# GoAir                                 240
# Jet Airways Business                    0
# Multiple carriers Premium economy       0
# Trujet                                  0
# Vistara Premium economy                 0
# Name: count, dtype: int64

# %%
df["Airline"].value_counts().plot(kind = "bar")
# Out:
# <Axes: xlabel='Airline'>

# %% [markdown]
# ## Source

# %%
df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      2019-03-24  Banglore   New Delhi              BLR → DEL
# 1    Air India      2019-05-01   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways      2019-06-09     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      2019-05-12   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      2019-03-01  Banglore   New Delhi        BLR → NAG → DEL
#
#          Dep_Time    Arrival_Time        Duration Total_Stops Additional_Info  \
# 0 0 days 22:20:00 0 days 18:02:00 0 days 02:50:00    non-stop         No info
# 1 0 days 05:50:00 0 days 13:15:00 0 days 07:25:00     2 stops         No info
# 2 0 days 09:25:00 1 days 21:50:00 0 days 19:00:00     2 stops         No info
# 3 0 days 18:05:00 0 days 23:30:00 0 days 05:25:00      1 stop         No info
# 4 0 days 16:50:00 0 days 21:35:00 0 days 04:45:00      1 stop         No info
#
#    Price
# 0   3897
# 1   7662
# ...

# %%
df["Source"].value_counts()   # Data is approximately normally distributed.

df["Source"].value_counts().plot(kind = "bar")
# Out:
# <Axes: xlabel='Source'>

# %%
sns.boxplot(df, x = df["Source"], y = df["Price"])
plt.plot()
# Out:
# D:\Python\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# []

# %%
df.groupby("Source")["Price"].sum()
# Out:
# C:\Users\DIWAKAR SINGH\AppData\Local\Temp\ipykernel_3100\943228635.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby("Source")["Price"].sum()
# Source
# Banglore    28341035
# Chennai      3277281
# Delhi       70603422
# Kolkata     40687374
# Mumbai       7347919
# Name: Price, dtype: int64

# %%
# Fetch the prices which are greater than 40000  ( Here we are also doing the Preprocessing of the Price column as well. )

df[df["Price"] > 40000]

df[df["Price"] > 40000]["Source"].value_counts()  # These are the Outliers, since their amount is less remove them
# Out:
# Source
# Kolkata     7
# Delhi       4
# Banglore    3
# Chennai     0
# Mumbai      0
# Name: count, dtype: int64

# %%
# Filtering the values with fare prices of less then 40000.

df = df[~(df["Price"] > 40000)]

# %%
df.shape
# Out:
# (13310, 11)

# %%
df.head(2)
# Out:
#      Airline Date_of_Journey    Source Destination                  Route  \
# 0     IndiGo      2019-03-24  Banglore   New Delhi              BLR → DEL
# 1  Air India      2019-05-01   Kolkata    Banglore  CCU → IXR → BBI → BLR
#
#          Dep_Time    Arrival_Time        Duration Total_Stops Additional_Info  \
# 0 0 days 22:20:00 0 days 18:02:00 0 days 02:50:00    non-stop         No info
# 1 0 days 05:50:00 0 days 13:15:00 0 days 07:25:00     2 stops         No info
#
#    Price
# 0   3897
# 1   7662

# %% [markdown]
# ## Date-Of-Journey
#
# **Conclusion: -**
#
# * The data contains the values of year 2019 only.
# * The df contains only the data of 4 months which are, March, April, May and June.
# * The df contains the data of some specific dates on which the passengers travelled.
# * Most of the Passengers travelled in the month of May and June ( Probably in the Summer Vacation ).
# * In the given df the Change in month or date does not have much difference in the price, so we can say that the data is uniform

# %%
# Printing the Year of the Dates-Of-Journey, to check how many years data I have

df["Date_of_Journey"].dt.year.value_counts()  # The data contains the values of year 2019 only
# Out:
# Date_of_Journey
# 2019    13310
# Name: count, dtype: int64

# %%
# Printing the Month of the Dates-Of-Journey, to check how many years data I have

df["Date_of_Journey"].dt.month.value_counts()  # The df contains only the data of 4 months which are, March, April, May and June
# Out:
# Date_of_Journey
# 5    4326
# 6    4279
# 3    3379
# 4    1326
# Name: count, dtype: int64

# %%
# Plotting the Distribution of months of the Date-Of-Journey column.

df["Date_of_Journey"].dt.month.value_counts().plot(kind = "bar")
plt.xlabel("Month of the Journey")
plt.ylabel("No. of Passengers Travelled")
plt.show()

# %%
# Plotting the Distribution of months of the Date-Of-Journey column.

df["Date_of_Journey"].dt.month.value_counts().plot(kind = "kde")
plt.xlabel("No. of Passengers Travelled")
plt.show()

# %%
# Printing the Dates of the Dates-Of-Journey, to check how many unique dates I have.

df["Date_of_Journey"].dt.day.value_counts()  # The df contains the data of some specific dates on which the passengers travelled
# Out:
# Date_of_Journey
# 9     1768
# 6     1621
# 21    1352
# 27    1350
# 1     1342
# 24    1305
# 15    1249
# 12    1211
# 3     1078
# 18    1034
# Name: count, dtype: int64

# %%
# Plotting the Distribution of Days of the Date-Of-Journey column.

df["Date_of_Journey"].dt.day.value_counts().plot(kind = "bar")
plt.xlabel("Days")
plt.ylabel("No. of people's travelled each day")
plt.show()

# %%
# Plotting the Distribution of Days of the Date-Of-Journey column.

df["Date_of_Journey"].dt.day.value_counts().plot(kind = "kde")
plt.xlabel("No. of people's travelled each day")
plt.show()

# %%
# Plotting the relationship between Date-Of-Journey and Price

sns.barplot(df, x = df["Date_of_Journey"], y = df["Price"])
plt.xticks(rotation = "vertical")
plt.show()

# %%
# Plotting the relationship between Date and Price

sns.barplot(df, x = df["Date_of_Journey"].dt.day, y = df["Price"])
plt.xticks(rotation = "vertical")
plt.show()  # The graph shows the Prices are normally distributed.

# %%
# Plotting the relationship between Date and Price

sns.barplot(df, x = df["Date_of_Journey"].dt.month, y = df["Price"])
plt.xticks(rotation = "vertical")
plt.show()

# %%
df.head(2)
# Out:
#      Airline Date_of_Journey    Source Destination                  Route  \
# 0     IndiGo      2019-03-24  Banglore   New Delhi              BLR → DEL
# 1  Air India      2019-05-01   Kolkata    Banglore  CCU → IXR → BBI → BLR
#
#          Dep_Time    Arrival_Time        Duration Total_Stops Additional_Info  \
# 0 0 days 22:20:00 0 days 18:02:00 0 days 02:50:00    non-stop         No info
# 1 0 days 05:50:00 0 days 13:15:00 0 days 07:25:00     2 stops         No info
#
#    Price
# 0   3897
# 1   7662

# %% [markdown]
# ## Destination

# %%
df["Destination"].value_counts()
# Out:
# Destination
# Cochin       5660
# Banglore     3574
# Delhi        1581
# New Delhi    1158
# Hyderabad     882
# Kolkata       455
# Name: count, dtype: int64

# %%
df["Destination"].value_counts().plot(kind = "bar")
# Out:
# <Axes: xlabel='Destination'>

# %%
sns.boxplot(df, x = df["Destination"], y = df["Price"])
plt.show()
# Out:
# D:\Python\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %%
df.groupby(df["Destination"])["Price"].sum()
# Out:
# C:\Users\DIWAKAR SINGH\AppData\Local\Temp\ipykernel_3100\2792146351.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(df["Destination"])["Price"].sum()
# Destination
# Banglore     40354002
# Cochin       70408098
# Delhi        12795516
# Hyderabad     7347919
# Kolkata       3277281
# New Delhi    15381041
# Name: Price, dtype: int64

# %%
df[df["Price"] > 26000].shape
# Out:
# (347, 11)

# %%
df = df[df["Price"] < 26000]    # Preprocessing Price column

# %%
df.shape
# Out:
# (12963, 11)

# %%
df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      2019-03-24  Banglore   New Delhi              BLR → DEL
# 1    Air India      2019-05-01   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways      2019-06-09     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      2019-05-12   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      2019-03-01  Banglore   New Delhi        BLR → NAG → DEL
#
#          Dep_Time    Arrival_Time        Duration Total_Stops Additional_Info  \
# 0 0 days 22:20:00 0 days 18:02:00 0 days 02:50:00    non-stop         No info
# 1 0 days 05:50:00 0 days 13:15:00 0 days 07:25:00     2 stops         No info
# 2 0 days 09:25:00 1 days 21:50:00 0 days 19:00:00     2 stops         No info
# 3 0 days 18:05:00 0 days 23:30:00 0 days 05:25:00      1 stop         No info
# 4 0 days 16:50:00 0 days 21:35:00 0 days 04:45:00      1 stop         No info
#
#    Price
# 0   3897
# 1   7662
# ...

# %% [markdown]
# ## Dep_Time

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12963 entries, 0 to 13352
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          12963 non-null  category
#  1   Date_of_Journey  12963 non-null  datetime64[ns]
#  2   Source           12963 non-null  category
#  3   Destination      12963 non-null  category
#  4   Route            12962 non-null  object
#  5   Dep_Time         12963 non-null  timedelta64[ns]
#  6   Arrival_Time     12963 non-null  timedelta64[ns]
#  7   Duration         12963 non-null  timedelta64[ns]
#  8   Total_Stops      12962 non-null  category
#  9   Additional_Info  12963 non-null  category
#  10  Price            12963 non-null  int64
# dtypes: category(5), datetime64[ns](1), int64(1), object(1), timedelta64[ns](3)
# memory usage: 773.6+ KB

# %%
df["Dep_Time"].describe()   # Data is evenly distributed.
# Out:
# count                        12963
# mean     0 days 12:55:09.858828974
# std      0 days 05:43:59.341768592
# min                0 days 00:20:00
# 25%                0 days 08:00:00
# 50%                0 days 11:55:00
# 75%                0 days 18:05:00
# max                0 days 23:55:00
# Name: Dep_Time, dtype: object

# %%
# Plotting histogram to see the timedelta distribution of the data.

df['Dep_Time'].dt.total_seconds().plot(kind='hist', title='Timedelta Distribution')
plt.xlabel('Total Seconds')
plt.ylabel('Frequency')
plt.show()

# %%
# Plotting kde to see the timedelta distribution of the data.

df['Dep_Time'].dt.total_seconds().plot(kind='kde', title='Timedelta Distribution')
plt.xlabel('Total Seconds')
plt.ylabel('Frequency')
plt.show() # Deprture Time is somehow evenly distributed, most of the flights take off soon or late.

# %% [markdown]
# ## Arrival Time

# %%
df.head(2)
# Out:
#      Airline Date_of_Journey    Source Destination                  Route  \
# 0     IndiGo      2019-03-24  Banglore   New Delhi              BLR → DEL
# 1  Air India      2019-05-01   Kolkata    Banglore  CCU → IXR → BBI → BLR
#
#          Dep_Time    Arrival_Time        Duration Total_Stops Additional_Info  \
# 0 0 days 22:20:00 0 days 18:02:00 0 days 02:50:00    non-stop         No info
# 1 0 days 05:50:00 0 days 13:15:00 0 days 07:25:00     2 stops         No info
#
#    Price
# 0   3897
# 1   7662

# %%
df["Arrival_Time"].describe()
# Out:
# count                        12963
# mean     1 days 06:57:31.751909280
# std      0 days 23:07:57.161575639
# min                0 days 01:02:00
# 25%                0 days 16:10:00
# 50%                0 days 21:00:00
# 75%                1 days 21:47:00
# max                4 days 18:53:00
# Name: Arrival_Time, dtype: object

# %%
# Plotting histogram to see the timedelta distribution of the data.

df['Arrival_Time'].dt.total_seconds().plot(kind='hist', title='Timedelta Distribution')
plt.xlabel('Total Seconds')
plt.ylabel('Frequency')
plt.show()

# %%
# Plotting kde to see the timedelta distribution of the data.

df['Arrival_Time'].dt.total_seconds().plot(kind='kde', title='Timedelta Distribution')
plt.xlabel('Total Seconds')
plt.ylabel('Frequency')
plt.show()  # Only some of the journeys have largers duration, most of the duration is short.

# %% [markdown]
# ## Duration

# %%
df["Duration"].describe()
# Out:
# count                        12963
# mean     0 days 10:41:32.710020828
# std      0 days 08:27:14.230185817
# min                0 days 00:05:00
# 25%                0 days 02:50:00
# 50%                0 days 08:35:00
# 75%                0 days 15:30:00
# max                1 days 23:40:00
# Name: Duration, dtype: object

# %%
# Plotting histogram to see the timedelta distribution of the data.

df['Duration'].dt.total_seconds().plot(kind='hist', title='Timedelta Distribution')
plt.xlabel('Total Seconds')
plt.ylabel('Frequency')
plt.show()

# %%
# Plotting histogram to see the timedelta distribution of the data.

df['Duration'].dt.total_seconds().plot(kind='kde', title='Timedelta Distribution')
plt.xlabel('Total Seconds')
plt.ylabel('Frequency')
plt.show()  # Only some of the journeys have largers duration, most of the duration is short.

# %% [markdown]
# ## Total Stops
#
# + Needs to be encoded using OHE

# %%
df.sample(5)
# Out:
#                  Airline Date_of_Journey    Source Destination  \
# 1673         Jet Airways      2019-06-12   Kolkata    Banglore
# 5055           Air India      2019-05-27  Banglore       Delhi
# 11116             IndiGo      2019-05-21   Chennai     Kolkata
# 8883   Multiple carriers      2019-04-09     Delhi      Cochin
# 9523         Jet Airways      2019-04-01   Kolkata    Banglore
#
#                  Route        Dep_Time    Arrival_Time        Duration  \
# 1673   CCU → BOM → BLR 0 days 06:30:00 0 days 16:20:00 0 days 09:50:00
# 5055         BLR → DEL 0 days 17:00:00 0 days 19:45:00 0 days 02:45:00
# 11116        MAA → CCU 0 days 05:15:00 0 days 07:40:00 0 days 02:25:00
# 8883   DEL → BOM → COK 0 days 11:40:00 2 days 03:10:00 0 days 13:50:00
# 9523   CCU → BOM → BLR 0 days 21:10:00 1 days 18:22:00 0 days 12:10:00
#
#       Total_Stops              Additional_Info  Price
# 1673       1 stop  In-flight meal not included   9899
# ...

# %%
# Checking the Number of unique values in Total Stops Column

df["Total_Stops"].value_counts()
# Out:
# Total_Stops
# 1 stop      6813
# non-stop    4251
# 2 stops     1840
# 3 stops       56
# 4 stops        2
# Name: count, dtype: int64

# %%
# Since the values of the 3 and 4 stops are very less so, I removed theose entries.  

df = df[(df["Total_Stops"] != "3 stops") & (df["Total_Stops"] != "4 stops")]

# %%
df["Total_Stops"].value_counts().plot(kind = "bar")
# Out:
# <Axes: xlabel='Total_Stops'>

# %%
sns.countplot(x = df["Total_Stops"], data = df)
plt.show()
# Out:
# D:\Python\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %%
df["Total_Stops"].value_counts().plot(kind = "pie", autopct = "%0.1f%%", explode = np.ones(5) * 0.05)
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ## Additional Info
#
# + Some of the Values of the Additional Info column was very less so removing them.

# %%
df.head(2)
# Out:
#      Airline Date_of_Journey    Source Destination                  Route  \
# 0     IndiGo      2019-03-24  Banglore   New Delhi              BLR → DEL
# 1  Air India      2019-05-01   Kolkata    Banglore  CCU → IXR → BBI → BLR
#
#          Dep_Time    Arrival_Time        Duration Total_Stops Additional_Info  \
# 0 0 days 22:20:00 0 days 18:02:00 0 days 02:50:00    non-stop         No info
# 1 0 days 05:50:00 0 days 13:15:00 0 days 07:25:00     2 stops         No info
#
#    Price
# 0   3897
# 1   7662

# %%
df["Additional_Info"].isna().sum()
# Out:
# 0

# %%
# Checking the number of Unique Values in the Additional Info Column

df["Additional_Info"].value_counts()
# Out:
# Additional_Info
# No info                         10110
# In-flight meal not included      2387
# No check-in baggage included      386
# 1 Long layover                     12
# Change airports                     6
# No Info                             3
# Red-eye flight                      1
# 1 Short layover                     0
# 2 Long layover                      0
# Business class                      0
# Name: count, dtype: int64

# %%
df["Additional_Info"].value_counts()[df["Additional_Info"].value_counts() > 20]
# Out:
# Additional_Info
# No info                         10110
# In-flight meal not included      2387
# No check-in baggage included      386
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (12905, 11)

# %%
# Only Keep the values whose value counts is greater than 20

filtered_Additional_Info_Lst = df["Additional_Info"].value_counts()[df["Additional_Info"].value_counts() > 20].index.to_list()

df = df[df["Additional_Info"].isin(filtered_Additional_Info_Lst)]

# %%
filtered_Additional_Info_Lst
# Out:
# ['No info', 'In-flight meal not included', 'No check-in baggage included']

# %%
df.shape
# Out:
# (12883, 11)

# %%
df.head(3)
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      2019-03-24  Banglore   New Delhi              BLR → DEL
# 1    Air India      2019-05-01   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways      2019-06-09     Delhi      Cochin  DEL → LKO → BOM → COK
#
#          Dep_Time    Arrival_Time        Duration Total_Stops Additional_Info  \
# 0 0 days 22:20:00 0 days 18:02:00 0 days 02:50:00    non-stop         No info
# 1 0 days 05:50:00 0 days 13:15:00 0 days 07:25:00     2 stops         No info
# 2 0 days 09:25:00 1 days 21:50:00 0 days 19:00:00     2 stops         No info
#
#    Price
# 0   3897
# 1   7662
# 2  13882

# %%
df["Additional_Info"].value_counts().plot(kind = "bar")
# Out:
# <Axes: xlabel='Additional_Info'>

# %%
df["Additional_Info"].value_counts().plot(kind = "pie", autopct = "%0.1f%%", explode = np.ones(10) * 0.05)
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ## Price
#
# + Price Column can be scaled.

# %%
df.head(2)
# Out:
#      Airline Date_of_Journey    Source Destination                  Route  \
# 0     IndiGo      2019-03-24  Banglore   New Delhi              BLR → DEL
# 1  Air India      2019-05-01   Kolkata    Banglore  CCU → IXR → BBI → BLR
#
#          Dep_Time    Arrival_Time        Duration Total_Stops Additional_Info  \
# 0 0 days 22:20:00 0 days 18:02:00 0 days 02:50:00    non-stop         No info
# 1 0 days 05:50:00 0 days 13:15:00 0 days 07:25:00     2 stops         No info
#
#    Price
# 0   3897
# 1   7662

# %%
df["Price"].describe()
# Out:
# count    12883.000000
# mean     10753.756967
# std       5636.433639
# min       1759.000000
# 25%       6072.500000
# 50%      10262.000000
# 75%      14388.000000
# max      25985.000000
# Name: Price, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12883 entries, 0 to 13352
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          12883 non-null  category
#  1   Date_of_Journey  12883 non-null  datetime64[ns]
#  2   Source           12883 non-null  category
#  3   Destination      12883 non-null  category
#  4   Route            12882 non-null  object
#  5   Dep_Time         12883 non-null  timedelta64[ns]
#  6   Arrival_Time     12883 non-null  timedelta64[ns]
#  7   Duration         12883 non-null  timedelta64[ns]
#  8   Total_Stops      12882 non-null  category
#  9   Additional_Info  12883 non-null  category
#  10  Price            12883 non-null  int64
# dtypes: category(5), datetime64[ns](1), int64(1), object(1), timedelta64[ns](3)
# memory usage: 768.8+ KB

# %%
# Plotting histogram of the Dataset

sns.displot(df["Price"])
# Out:
# D:\Python\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Plotting kde plot of the Dataset

sns.displot(df["Price"], kind = "kde")
# Out:
# D:\Python\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Plotting BoxPlot to detect outliers
sns.boxplot(df["Price"])  # This shows price column has no outliers
# Out:
# <Axes: >

# %% [markdown]
# # Feature Extraction

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12883 entries, 0 to 13352
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          12883 non-null  category
#  1   Date_of_Journey  12883 non-null  datetime64[ns]
#  2   Source           12883 non-null  category
#  3   Destination      12883 non-null  category
#  4   Route            12882 non-null  object
#  5   Dep_Time         12883 non-null  timedelta64[ns]
#  6   Arrival_Time     12883 non-null  timedelta64[ns]
#  7   Duration         12883 non-null  timedelta64[ns]
#  8   Total_Stops      12882 non-null  category
#  9   Additional_Info  12883 non-null  category
#  10  Price            12883 non-null  int64
# dtypes: category(5), datetime64[ns](1), int64(1), object(1), timedelta64[ns](3)
# memory usage: 1.3+ MB

# %%
df.head(2)
# Out:
#      Airline Date_of_Journey    Source Destination                  Route  \
# 0     IndiGo      2019-03-24  Banglore   New Delhi              BLR → DEL
# 1  Air India      2019-05-01   Kolkata    Banglore  CCU → IXR → BBI → BLR
#
#          Dep_Time    Arrival_Time        Duration Total_Stops Additional_Info  \
# 0 0 days 22:20:00 0 days 18:02:00 0 days 02:50:00    non-stop         No info
# 1 0 days 05:50:00 0 days 13:15:00 0 days 07:25:00     2 stops         No info
#
#    Price
# 0   3897
# 1   7662

# %%
# Extracting day, month, year from Date_of_Journey column
df["Journey_Day"] = df["Date_of_Journey"].dt.day
df["Journey_Month"] = df["Date_of_Journey"].dt.month

# Extracting the Hour and Minute data from the Dep_Time
df["Dep_Hour"] = df["Dep_Time"].dt.components.hours
df["Dep_Minutes"] = df["Dep_Time"].dt.components.minutes

# Extracting the Hour and Minute data from the Arrival_Time
df["Arrival_Hour"] = df["Arrival_Time"].dt.components.hours
df["Arrival_Minutes"] = df["Arrival_Time"].dt.components.minutes

# Extracting the Hour and Minute data from the Duration
df["Duration_Hour"] = df["Duration"].dt.components.hours
df["Duration_Minutes"] = df["Duration"].dt.components.minutes

# %%
# Drop Date_of_Journey, Dep_Time, Arrival_Time and Duration column

df.drop(columns= ["Date_of_Journey", "Dep_Time", "Arrival_Time", "Duration"], inplace= True)

# %%
df["Price"] = np.log(df["Price"])

# %%
df.head(3)
# Out:
#        Airline    Source Destination                  Route Total_Stops  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL    non-stop
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR     2 stops
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK     2 stops
#
#   Additional_Info     Price  Journey_Day  Journey_Month  Dep_Hour  \
# 0         No info  8.267962           24              3        22
# 1         No info  8.944028            1              5         5
# 2         No info  9.538348            9              6         9
#
#    Dep_Minutes  Arrival_Hour  Arrival_Minutes  Duration_Hour  Duration_Minutes
# 0           20            18                2              2                50
# 1           50            13               15              7                25
# 2           25            21               50             19                 0

# %%
df[["Journey_Day", "Journey_Month", "Dep_Hour", "Dep_Minutes", "Arrival_Hour", "Arrival_Minutes", "Duration_Hour", 
   "Duration_Minutes", "Price"]].corr()["Price"]
# Out:
# Journey_Day        -0.097532
# Journey_Month      -0.022953
# Dep_Hour            0.001829
# Dep_Minutes        -0.042810
# Arrival_Hour        0.122244
# Arrival_Minutes    -0.057253
# Duration_Hour       0.397053
# Duration_Minutes   -0.099554
# Price               1.000000
# Name: Price, dtype: float64

# %%
# df.drop(columns= ["Journey_Day", "Journey_Month", "Dep_Hour", "Dep_Minutes", "Arrival_Minutes",
#                   "Duration_Minutes"], inplace= True)

# %% [markdown]
# # Train Test Split

# %%
df.head(2)
# Out:
#      Airline    Source Destination                  Route Total_Stops  \
# 0     IndiGo  Banglore   New Delhi              BLR → DEL    non-stop
# 1  Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR     2 stops
#
#   Additional_Info     Price  Journey_Day  Journey_Month  Dep_Hour  \
# 0         No info  8.267962           24              3        22
# 1         No info  8.944028            1              5         5
#
#    Dep_Minutes  Arrival_Hour  Arrival_Minutes  Duration_Hour  Duration_Minutes
# 0           20            18                2              2                50
# 1           50            13               15              7                25

# %%
df.drop(columns=["Route"], inplace= True)

# %%
df.head(2)
# Out:
#      Airline    Source Destination Total_Stops Additional_Info     Price  \
# 0     IndiGo  Banglore   New Delhi    non-stop         No info  8.267962
# 1  Air India   Kolkata    Banglore     2 stops         No info  8.944028
#
#    Journey_Day  Journey_Month  Dep_Hour  Dep_Minutes  Arrival_Hour  \
# 0           24              3        22           20            18
# 1            1              5         5           50            13
#
#    Arrival_Minutes  Duration_Hour  Duration_Minutes
# 0                2              2                50
# 1               15              7                25

# %%
from sklearn.model_selection import train_test_split

# %%
x = df.iloc[:, [0, 1, 2, 3, 4, 6, 7, 8, 9, 10, 11, 12, 13]]
y = df.iloc[:, 5]

# %%
x.head(2)
# Out:
#      Airline    Source Destination Total_Stops Additional_Info  Journey_Day  \
# 0     IndiGo  Banglore   New Delhi    non-stop         No info           24
# 1  Air India   Kolkata    Banglore     2 stops         No info            1
#
#    Journey_Month  Dep_Hour  Dep_Minutes  Arrival_Hour  Arrival_Minutes  \
# 0              3        22           20            18                2
# 1              5         5           50            13               15
#
#    Duration_Hour  Duration_Minutes
# 0              2                50
# 1              7                25

# %%
y.head(2)
# Out:
# 0    8.267962
# 1    8.944028
# Name: Price, dtype: float64

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size= 0.2, random_state= 2)

# %%
x_train.shape
# Out:
# (10306, 13)

# %%
x_test.shape
# Out:
# (2577, 13)

# %%
y_train.shape
# Out:
# (10306,)

# %%
y_test.shape
# Out:
# (2577,)

# %% [markdown]
# # Model Selection and Model Training

# %%
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor
from xgboost import XGBRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.preprocessing import OneHotEncoder, StandardScaler

from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# %%
x_train.head(2)
# Out:
#                  Airline Source Destination Total_Stops Additional_Info  \
# 5070   Multiple carriers  Delhi      Cochin      1 stop         No info
# 12432        Jet Airways  Delhi      Cochin     2 stops         No info
#
#        Journey_Day  Journey_Month  Dep_Hour  Dep_Minutes  Arrival_Hour  \
# 5070            15              5        17           30             3
# 12432           18              5        19           10            19
#
#        Arrival_Minutes  Duration_Hour  Duration_Minutes
# 5070                16              8                 0
# 12432               19             23                50

# %%
# y_train = np.log(y_train)
# y_test = np.log(y_test)

# %% [markdown]
# # Training the Model's

# %% [markdown]
# # DecisionTreeRegressor

# %%
# One Hot Encoding the Categorical columns
trf1 = ColumnTransformer(transformers=[
    ("ohe_trf", OneHotEncoder(sparse=False, drop= "first"), [0, 1, 2, 3, 4]),
    ("standard_scaler_trf", StandardScaler(), [5, 6, 7, 8, 9, 10, 11, 12])
], remainder= "passthrough")

# Initializing the DecisionTreeRegressor model
trf2 = DecisionTreeRegressor(max_depth= 3, min_samples_leaf= 1, min_samples_split= 2)

# Creating Pipeline
pipe = Pipeline([
    ("trf1", trf1),
    ("trf2", trf2)
])

# Training the Model
pipe.fit(x_train, y_train)   

y_pred = pipe.predict(x_test)

# Printing the Metrics
print("R2_Score -  ", r2_score(y_test, y_pred))
print("MAE      -  ", mean_absolute_error(y_test, y_pred))
print("MSE      -  ", mean_squared_error(y_test, y_pred))
# Out:
# R2_Score -   0.3622886244992901
# MAE      -   0.3567059463338684
# MSE      -   0.2137750471211554
# D:\Python\Lib\site-packages\sklearn\preprocessing\_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %% [markdown]
# # RandomForestRegressor GridSearchCV

# %%
from sklearn.model_selection import GridSearchCV

# GridSearchCV of RandomForestRegressor
param_grid = {
    'trf2__max_depth': [3, 5, 7, 10],
    'trf2__min_samples_split': [2, 5, 10],
    'trf2__min_samples_leaf': [1, 2, 4]
}

# GridSearchCV of XGBRegressor ( This is giving error for some reason )
# param_grid = {
#     'n_estimators': [100, 200, 300],  # Number of boosting rounds
#     'learning_rate': [0.1, 0.01, 0.001],  # Boosting learning rate
#     'max_depth': [3, 5, 7],  # Maximum tree depth for base learners
#     'colsample_bytree': [0.6, 0.8, 1.0]  # Subsample ratio of columns when constructing each tree
# }

# Perform grid search
grid_search = GridSearchCV(pipe, param_grid, cv=5, scoring='neg_mean_squared_error')
grid_search.fit(x_train, y_train)

# Get the best hyperparameters
best_params = grid_search.best_params_
# Out:
# D:\Python\Lib\site-packages\sklearn\preprocessing\_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# D:\Python\Lib\site-packages\sklearn\preprocessing\_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# D:\Python\Lib\site-packages\sklearn\preprocessing\_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# ...

# %%
best_params
# Out:
# {'trf2__max_depth': 3,
#  'trf2__min_samples_leaf': 1,
#  'trf2__min_samples_split': 2}

# %% [markdown]
# # AdaBoostRegressor

# %%
# One Hot Encoding the Categorical columns
trf1 = ColumnTransformer(transformers=[
    ("ohe_trf", OneHotEncoder(sparse=False, drop= "first"), [0, 1, 2, 3, 4]),
    ("standard_scaler_trf", StandardScaler(), [5, 6, 7, 8, 9, 10, 11, 12])
], remainder= "passthrough")

# Initializing the AdaBoAdaBoostRegressor model
trf2 = AdaBoostRegressor(n_estimators= 100, learning_rate= 0.1, loss = "linear")

# Creating Pipeline
pipe = Pipeline([
    ("trf1", trf1),
    ("trf2", trf2)
])

# Training the Model
pipe.fit(x_train, y_train)   

y_pred = pipe.predict(x_test)

# Printing the Metrics
print("R2_Score -  ", r2_score(y_test, y_pred))
print("MAE      -  ", mean_absolute_error(y_test, y_pred))
print("MSE      -  ", mean_squared_error(y_test, y_pred) )
# Out:
# D:\Python\Lib\site-packages\sklearn\preprocessing\_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# R2_Score -   0.3222005355779882
# MAE      -   0.38215389923888016
# MSE      -   0.22721346680030824

# %% [markdown]
# # XGBRegressor

# %%
# One Hot Encoding the Categorical columns
trf1 = ColumnTransformer(transformers=[
    ("ohe_trf", OneHotEncoder(sparse=False, drop= "first"), [0, 1, 2, 3, 4]),
    ("standard_scaler_trf", StandardScaler(), [5, 6, 7, 8, 9, 10, 11, 12])
], remainder= "passthrough")

# Initializing the XGBRegressor model      # r2 = 46
trf2 = XGBRegressor(
    n_estimators=100,  # Number of boosting rounds
    learning_rate=0.1,  # Boosting learning rate
    max_depth=3,  # Maximum tree depth for base learners
    subsample=0.8,  # Subsample ratio of the training instances
    colsample_bytree=0.8,  # Subsample ratio of columns when constructing each tree
    objective='reg:squarederror'  # Specify the learning task and the objective
)

# Creating Pipeline
pipe = Pipeline([
    ("trf1", trf1),
    ("trf2", trf2)
])

# Training the Model
pipe.fit(x_train, y_train)   

y_pred = pipe.predict(x_test)

# Printing the Metrics
print("R2_Score -  ", r2_score(y_test, y_pred))
print("MAE      -  ", mean_absolute_error(y_test, y_pred))
print("MSE      -  ", mean_squared_error(y_test, y_pred) )
# Out:
# R2_Score -   0.46326519948159395
# MAE      -   0.3023935769662827
# MSE      -   0.17992545167050805
# D:\Python\Lib\site-packages\sklearn\preprocessing\_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %% [markdown]
# # XGBRegressor GridSearchCV

# %%
# from sklearn.model_selection import GridSearchCV

# # GridSearchCV of XGBRegressor ( This is giving error for some reason )
# # param_grid = {
# #     'n_estimators': [100, 200, 300],  # Number of boosting rounds
# #     'learning_rate': [0.1, 0.01, 0.001],  # Boosting learning rate
# #     'max_depth': [3, 5, 7],  # Maximum tree depth for base learners
# #     'colsample_bytree': [0.6, 0.8, 1.0]  # Subsample ratio of columns when constructing each tree
# # }

# # Perform grid search
# grid_search = GridSearchCV(pipe, param_grid, cv=5, scoring='neg_mean_squared_error')
# grid_search.fit(x_train, y_train)

# # Get the best hyperparameters
# best_params = grid_search.best_params_

# %%
# best_params

# %% [markdown]
# # Linear Regression

# %%
# One Hot Encoding the Categorical columns
trf1 = ColumnTransformer(transformers=[
    ("ohe_trf", OneHotEncoder(sparse=False, drop= "first"), [0, 1, 2, 3, 4]),
    ("standard_scaler_trf", StandardScaler(), [5, 6, 7, 8, 9, 10, 11, 12])
], remainder= "passthrough")

# Initializing the LinearRegression model     # r2 = 41
trf2 = LinearRegression(n_jobs=1)  

# Creating Pipeline
pipe = Pipeline([
    ("trf1", trf1),
    ("trf2", trf2)
])

# Training the Model
pipe.fit(x_train, y_train)   

y_pred = pipe.predict(x_test)

# Printing the Metrics
print("R2_Score -  ", r2_score(y_test, y_pred))
print("MAE      -  ", mean_absolute_error(y_test, y_pred))
print("MSE      -  ", mean_squared_error(y_test, y_pred) )
# Out:
# R2_Score -   0.41911286065352227
# MAE      -   0.32550163997914744
# MSE      -   0.1947262983796785
# D:\Python\Lib\site-packages\sklearn\preprocessing\_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %% [markdown]
# # SVR

# %%
# One Hot Encoding the Categorical columns
trf1 = ColumnTransformer(transformers=[
    ("ohe_trf", OneHotEncoder(sparse=False, drop= "first"), [0, 1, 2, 3, 4]),
    ("standard_scaler_trf", StandardScaler(), [5, 6, 7, 8, 9, 10, 11, 12])
], remainder= "passthrough")

# Initializing the SVR model
trf2 = SVR(
    kernel='rbf',  # RBF kernel
    C=1.0,  # Regularization parameter
    epsilon=0.1,  # Epsilon parameter
    gamma='scale'  # Gamma parameter
)

# Creating Pipeline
pipe = Pipeline([
    ("trf1", trf1),
    ("trf2", trf2)
])

# Training the Model
pipe.fit(x_train, y_train)   

y_pred = pipe.predict(x_test)

# Printing the Metrics
print("R2_Score -  ", r2_score(y_test, y_pred))
print("MAE      -  ", mean_absolute_error(y_test, y_pred))
print("MSE      -  ", mean_squared_error(y_test, y_pred) )
# Out:
# D:\Python\Lib\site-packages\sklearn\preprocessing\_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# R2_Score -   0.4335708303492136
# MAE      -   0.25090838800588877
# MSE      -   0.18987966513506077

# %% [markdown]
# ## SVR Grid SearchCV

# %%
from sklearn.model_selection import GridSearchCV

# Define the ColumnTransformer
trf1 = ColumnTransformer(transformers=[
    ("ohe_trf", OneHotEncoder(sparse=False, drop="first"), [0, 1, 2, 3, 4]),
    ("standard_scaler_trf", StandardScaler(), [5, 6, 7, 8, 9, 10, 11, 12])
], remainder="passthrough")

# Initialize the SVR model with custom parameters
svr_model = SVR(C=0.1, kernel='rbf', gamma='scale')

# Create the Pipeline
pipe = Pipeline([
    ("trf1", trf1),
    ("trf2", svr_model)
])

# Define the parameter grid for GridSearchCV
param_grid = {
    "trf2__C": [0.1, 1.0, 10.0],  # Example values for C
    "trf2__gamma": ["scale", "auto"]  # Example values for gamma
}

# Perform grid search to find the best parameters
grid_search = GridSearchCV(pipe, param_grid, cv=5)
grid_search.fit(x_train, y_train)

# Get the best parameters
best_params = grid_search.best_params_
# Out:
# D:\Python\Lib\site-packages\sklearn\preprocessing\_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# D:\Python\Lib\site-packages\sklearn\preprocessing\_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# D:\Python\Lib\site-packages\sklearn\preprocessing\_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# ...

# %%
print(best_params)
# Out:
# {'trf2__C': 0.1, 'trf2__gamma': 'scale'}
